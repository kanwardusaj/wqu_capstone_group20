# %% [markdown]
# # WORLDQUANT UNIVERSITY
# ## CAPSTONE PROJECT - GROUP 20
# ## TITLE : CODE TO TEST THE WEAK FORM OF EFFICIENT MARKET HYPOTHESIS

# %% [markdown]
# ##### Importing packages

# %%
import numpy as np
import pandas_datareader
import pandas as pd
from pandas_datareader import data

# %% [markdown]
# ####   Adjusted Close Prices for Ten Selected Stocks Over 15 - Year Period

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
start_date = '2005-01-01'
end_date = '2020-01-01'
ticker_list = ['AAPL', 'EBAY', 'IBM', 'MSFT', 'CSL', 'KO', 'HPQ', 'TGT', 'CNSL', 'DIS']
data = data.get_data_yahoo(ticker_list, start_date, end_date)
data.head()
# Out:
# Attributes Adj Close                                                  \
# Symbols         AAPL CNSL        CSL        DIS       EBAY       HPQ
# Date
# 2005-01-03  3.913571  NaN  24.332512  22.605978  23.547733  5.844016
# 2005-01-04  3.953765  NaN  23.836397  22.362459  22.969929  5.805150
# 2005-01-05  3.988392  NaN  23.736414  22.240704  22.885319  5.830133
# 2005-01-06  3.991483  NaN  24.151752  22.273172  21.911301  5.819029
# 2005-01-07  4.282110  NaN  24.151752  22.054012  21.993843  5.785715
#
# Attributes                                              ...       Volume       \
# Symbols           IBM         KO       MSFT        TGT  ...         AAPL CNSL
# Date                                                    ...
# 2005-01-03  64.935944  10.565041  19.347652  36.803249  ...  172998000.0  NaN
# 2005-01-04  64.238380  10.417526  19.420000  36.405384  ...  274202600.0  NaN
# 2005-01-05  64.105545  10.369201  19.376589  36.433796  ...  170108400.0  NaN
# ...

# %% [markdown]
# #### A Plot of Ajdusted Close Prices of Selected Stocks(2005-2020)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data['Adj Close'].plot(figsize=(20, 10))
plt.title("Adjusted Close Price of various stocks - (2005-2020)", fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.xlabel('Year', fontsize=20)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %% [markdown]
# #### Plot of Individual Adjusted Close Prices for Selected Stocks

# %%
import statsmodels.formula.api as smf
from statsmodels.graphics.tsaplots import plot_acf
fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(321)
ax1.plot(data['Adj Close']['AAPL'])
ax1.set_title("Apple - Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
ax2 = fig.add_subplot(322)
ax2.plot(data['Adj Close']['CNSL'])
ax2.set_title("CNSL - Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
fig = plt.figure(figsize=(20, 10))
ax3 = fig.add_subplot(321)
ax3.plot(data['Adj Close']['CSL'])
ax3.set_title("CSL- Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
ax4 = fig.add_subplot(322)
ax4.plot(data['Adj Close']['DIS'])
ax4.set_title("DIS- Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
fig = plt.figure(figsize=(20, 10))
ax5 = fig.add_subplot(321)
ax5.plot(data['Adj Close']['EBAY'])
ax5.set_title("EBAY- Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
ax6 = fig.add_subplot(322)
ax6.plot(data['Adj Close']['HPQ'])
ax6.set_title("HPQ- Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
fig = plt.figure(figsize=(20, 10))
ax5 = fig.add_subplot(321)
ax5.plot(data['Adj Close']['IBM'])
ax5.set_title("IBM- Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
ax6 = fig.add_subplot(322)
ax6.plot(data['Adj Close']['KO'])
ax6.set_title("KO- Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
fig = plt.figure(figsize=(20, 10))
ax5 = fig.add_subplot(321)
ax5.plot(data['Adj Close']['MSFT'])
ax5.set_title("Microsoft- Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
ax6 = fig.add_subplot(322)
ax6.plot(data['Adj Close']['TGT'])
ax6.set_title("TGT- Adj Close-(2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Monthly Returns

# %%
data_monthly_returns = data['Adj Close'].resample('M').ffill().pct_change()
print(data_daily_returns.head())
# Out:
# Symbols         AAPL  CNSL       CSL       DIS      EBAY       HPQ       IBM  \
# Date
# 2005-01-03       NaN   NaN       NaN       NaN       NaN       NaN       NaN
# 2005-01-04  0.010270   NaN -0.020389 -0.010772 -0.024538 -0.006651 -0.010742
# 2005-01-05  0.008758   NaN -0.004195 -0.005445 -0.003684  0.004304 -0.002068
# 2005-01-06  0.000775   NaN  0.017498  0.001460 -0.042561 -0.001905 -0.003109
# 2005-01-07  0.072812   NaN  0.000000 -0.009840  0.003767 -0.005725 -0.004366
#
# Symbols           KO      MSFT       TGT
# Date
# 2005-01-03       NaN       NaN       NaN
# 2005-01-04 -0.013962  0.003739 -0.010811
# 2005-01-05 -0.004639 -0.002235  0.000780
# 2005-01-06  0.008339 -0.001120 -0.054212
# 2005-01-07  0.001216 -0.002991  0.010721

# %%
fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(data_daily_returns)
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("Various Stocks Daily returns (2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(data_monthly_returns)
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("Various Stocks Monthly returns (2005-2020)")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
fig = plt.figure(figsize=(20, 10))
data_monthly_returns.plot.hist(bins = 60)
plt.title("Monthly Stocks return data")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.ylabel("Percent %")
plt.xlabel("Monthly returns %")
plt.text(-0.35,3,"Extreme Low\nreturns")
plt.text(0.19,3,"Extreme High\nreturns")
plt.show()

# %%
fig = plt.figure(figsize=(20, 10))
data_daily_returns.plot.hist(bins = 60)
plt.title("Daily Stocks return data")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.ylabel("Percent %")
plt.xlabel("Daily returns %")
plt.text(-0.35,3,"Extreme Low\nreturns")
plt.text(0.19,3,"Extreme High\nreturns")
plt.show()

# %% [markdown]
# ### Stocks Monthly Cummulative Returns

# %%
data_monthly_returns = data['Adj Close'].resample('M').ffill().pct_change()

# %%
fig = plt.figure()
(data_monthly_returns + 1).cumprod().plot()
ax1.set_title("Various Stocks Cummulative returns")
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %% [markdown]
# ### Discriptive Statistics of Monthly Returns

# %%
data_monthly_returns.describe()
# Out:
# Symbols        AAPL        CNSL         CSL         DIS        EBAY  \
# count    179.000000  173.000000  179.000000  179.000000  179.000000
# mean       0.027563    0.005327    0.013431    0.012167    0.008331
# std        0.091792    0.100549    0.075510    0.062091    0.091345
# min       -0.329558   -0.510745   -0.224224   -0.189071   -0.317694
# 25%       -0.021709   -0.036190   -0.023007   -0.020771   -0.045448
# 50%        0.033790    0.015674    0.014471    0.011836    0.000000
# 75%        0.086060    0.061014    0.052209    0.046505    0.061894
# max        0.237701    0.237563    0.308658    0.233631    0.331055
#
# Symbols         HPQ         IBM          KO        MSFT         TGT
# count    179.000000  179.000000  179.000000  179.000000  179.000000
# mean       0.010789    0.005918    0.010152    0.013991    0.009590
# std        0.082081    0.058424    0.042489    0.065593    0.071831
# min       -0.259881   -0.236625   -0.166793   -0.163357   -0.182059
# ...

# %% [markdown]
# ### Variance of Monthly Returns

# %%
print(data_monthly_returns.var())
# Out:
# Symbols
# AAPL    0.008426
# CNSL    0.010110
# CSL     0.005702
# DIS     0.003855
# EBAY    0.008344
# HPQ     0.006737
# IBM     0.003413
# KO      0.001805
# MSFT    0.004302
# TGT     0.005160
# dtype: float64

# %% [markdown]
# ### Covariance of Monthly Returns

# %%
print(data_monthly_returns.cov())
# Out:
# Symbols      AAPL      CNSL       CSL       DIS      EBAY       HPQ       IBM  \
# Symbols
# AAPL     0.008426  0.001333  0.001136  0.001694  0.003299  0.002370  0.001942
# CNSL     0.001333  0.010110  0.001463  0.001086  0.002170  0.002726  0.001971
# CSL      0.001136  0.001463  0.005702  0.002168  0.002307  0.002199  0.001665
# DIS      0.001694  0.001086  0.002168  0.003855  0.002654  0.002240  0.001344
# EBAY     0.003299  0.002170  0.002307  0.002654  0.008344  0.002625  0.002801
# HPQ      0.002370  0.002726  0.002199  0.002240  0.002625  0.006737  0.002317
# IBM      0.001942  0.001971  0.001665  0.001344  0.002801  0.002317  0.003413
# KO       0.000853  0.001143  0.000518  0.000982  0.001041  0.000658  0.000586
# MSFT     0.002627  0.001909  0.000756  0.001701  0.002244  0.002213  0.001217
# TGT      0.001757  0.001200  0.001434  0.001578  0.002313  0.001465  0.001012
#
# Symbols        KO      MSFT       TGT
# Symbols
# AAPL     0.000853  0.002627  0.001757
# ...

# %% [markdown]
# ### Kurtosis of Montly Returns

# %%
print(data_monthly_returns.kurtosis())
# Out:
# Symbols
# AAPL    1.336905
# CNSL    4.083768
# CSL     2.595652
# DIS     1.471264
# EBAY    1.635941
# HPQ     0.260427
# IBM     2.282658
# KO      1.406303
# MSFT    0.942290
# TGT     0.939244
# dtype: float64

# %% [markdown]
# ### Correlation

# %%
print(data_monthly_returns.corr())
# Out:
# Symbols      AAPL      CNSL       CSL       DIS      EBAY       HPQ       IBM  \
# Symbols
# AAPL     1.000000  0.146368  0.163914  0.297233  0.393481  0.314574  0.362025
# CNSL     0.146368  1.000000  0.190873  0.173616  0.246536  0.327803  0.342506
# CSL      0.163914  0.190873  1.000000  0.462309  0.334514  0.354763  0.377430
# DIS      0.297233  0.173616  0.462309  1.000000  0.468016  0.439573  0.370480
# EBAY     0.393481  0.246536  0.334514  0.468016  1.000000  0.350062  0.524824
# HPQ      0.314574  0.327803  0.354763  0.439573  0.350062  1.000000  0.483142
# IBM      0.362025  0.342506  0.377430  0.370480  0.524824  0.483142  1.000000
# KO       0.218689  0.266294  0.161452  0.372406  0.268122  0.188777  0.236086
# MSFT     0.436316  0.286384  0.152709  0.417763  0.374484  0.410988  0.317573
# TGT      0.266438  0.166444  0.264424  0.353710  0.352575  0.248553  0.241216
#
# Symbols        KO      MSFT       TGT
# Symbols
# AAPL     0.218689  0.436316  0.266438
# ...

# %% [markdown]
# ### Autocorrelation

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from statsmodels.graphics import tsaplots

# %%
import matplotlib.pyplot as plot
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(figsize=(20, 10))
data = np.array(data)
plot.acorr(data, maxlags = 900)
plt.title('Autocorrelation of Monthly Returns')
plt.xlabel('lag')
plt.ylabel('Autocorrelation')
plot.show()

# %% [markdown]
# ### Quantile - Quantile Plot

# %%
from numpy.random import seed
from numpy.random import randn
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
# seed the random number generator
seed(1)
# generate univariate observations
data = data_monthly_returns
# q-q plot
qqplot(data, line='s')
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
pyplot.show()

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# ### DATA AND METHODOLOGY

# %% [markdown]
# The project analysis daily and monthly adjusted close prices of stock market indices for 10 selected stocks (APPL, IBM, CNSL, CSL, KO, EBAY, DIS, HPQ, TGT and MSFT). Observation are taken for the period 1/01/2005 – 01/01/2020 for which data are available. The analysis investigates the weak form of market efficiency using the selected stock prices from yahoo finance. It is to investigate whether the select stocks follows a random walk model or not. In effect, no arbitrage profits can be realized if the market is efficient.

# %% [markdown]
# ### Normality Test

# %% [markdown]
# From code run, the monthly returns are negatively skewed in all selected stocks for the selected period. This indicates large negative returns (minimum extreme value) beyond -0.4 which are larger than the higher positive returns (maximum extreme value) a little beyond 0.3. The kurtosis is positive across the selected stocks which indicates leptokurtic distribution of monthly returns. This shows higher peaks than expected from normal distributions. Further, a QQ-Plot performed in the code clearly indicates that the distribution of monthly returns does not follow a normal distribution as the tail ends have outliers clearly spread further away from the normal distribution line shown in red in code implementation. MSFT has the highest return of 2.49% with Std Dev of 6.55% whiles CNSL has least return of -5.10% with a Std Dev of 10.05%

# %% [markdown]
# ### Randomness Test

# %% [markdown]
# To analyze randomness of the monthly returns, autocorrelation plot of monthly returns was performed for the selected period. It is clear from the plot that, the null of the entire autocorrelation coefficients together equal to zero may be rejected. This indicates that historical returns can be used to correctly predict future returns of stocks. This further shows that the weak form of efficient market hypothesis does not hold entirely.
